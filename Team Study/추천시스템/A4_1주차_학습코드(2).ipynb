# %%
from tqdm import tqdm
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# Import required libraries
import os
import zipfile
from urllib.request import urlretrieve

# Define dataset URL and filename
url = 'http://files.grouplens.org/datasets/movielens/ml-100k.zip'
filename = 'ml-100k.zip'

# Download the dataset
urlretrieve(url, filename)

# Unzip the downloaded file
with zipfile.ZipFile(filename, 'r') as zip_ref:
    zip_ref.extractall('.')

# Print confirmation message
print('MovieLens 100k dataset downloaded and unzipped!')
# Out:
# MovieLens 100k dataset downloaded and unzipped!

# %%
ratings = pd.read_csv(
    "./ml-100k/u.data",
    sep="\t",
    usecols=[0, 1, 2, 3],
    names=["user", "item", "rating", "time"],
)

# %%
ratings
# Out:
#        user  item  rating       time
# 0       196   242       3  881250949
# 1       186   302       3  891717742
# 2        22   377       1  878887116
# 3       244    51       2  880606923
# 4       166   346       1  886397596
# ...     ...   ...     ...        ...
# 99995   880   476       3  880175444
# 99996   716   204       5  879795543
# 99997   276  1090       1  874795795
# 99998    13   225       2  882399156
# 99999    12   203       3  879959583
#
# [100000 rows x 4 columns]

# %%
ratings[ratings['user']==1]
# Out:
#        user  item  rating       time
# 202       1    61       4  878542420
# 305       1   189       3  888732928
# 333       1    33       4  878542699
# 334       1   160       4  875072547
# 478       1    20       4  887431883
# ...     ...   ...     ...        ...
# 92049     1    28       4  875072173
# 92487     1   172       5  874965478
# 94019     1   122       3  875241498
# 96699     1   152       5  878542589
# 99073     1    94       2  875072956
#
# [272 rows x 4 columns]

# %% [markdown]
# 기본 통계
# * 유저, 아이템 수
# * 유저별 평가 수 등..

# %%
ratings.groupby('user').agg({'item': len}).agg({'item':[min, max, np.mean, len]})
# Out:
# C:\Users\KimDongyoung\AppData\Local\Temp\ipykernel_36344\3715739895.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   ratings.groupby('user').agg({'item': len}).agg({'item':[min, max, np.mean, len]})
# C:\Users\KimDongyoung\AppData\Local\Temp\ipykernel_36344\3715739895.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ratings.groupby('user').agg({'item': len}).agg({'item':[min, max, np.mean, len]})
# C:\Users\KimDongyoung\AppData\Local\Temp\ipykernel_36344\3715739895.py:1: FutureWarning: The provided callable <function mean at 0x000002A54E3B3CE0> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ratings.groupby('user').agg({'item': len}).agg({'item':[min, max, np.mean, len]})
#             item
# min    20.000000
# max   737.000000
# mean  106.044539
# len   943.000000

# %%
ratings.groupby('item').agg({'user': len}).agg({'user':[min, max, np.mean, len]})
# Out:
# C:\Users\KimDongyoung\AppData\Local\Temp\ipykernel_36344\297988240.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   ratings.groupby('item').agg({'user': len}).agg({'user':[min, max, np.mean, len]})
# C:\Users\KimDongyoung\AppData\Local\Temp\ipykernel_36344\297988240.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ratings.groupby('item').agg({'user': len}).agg({'user':[min, max, np.mean, len]})
# C:\Users\KimDongyoung\AppData\Local\Temp\ipykernel_36344\297988240.py:1: FutureWarning: The provided callable <function mean at 0x000002A54E3B3CE0> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ratings.groupby('item').agg({'user': len}).agg({'user':[min, max, np.mean, len]})
#              user
# min      1.000000
# max    583.000000
# mean    59.453032
# len   1682.000000

# %%
ratings.groupby('rating').agg({'item':len})
# Out:
#          item
# rating
# 1        6110
# 2       11370
# 3       27145
# 4       34174
# 5       21201

# %%
ratings.groupby('rating').agg({'item':len}).plot.bar()
# Out:
# <Axes: xlabel='rating'>

# %% [markdown]
# 전처리
# * user, item 인덱스 0부터 가공
# * explicit to implicit
# * train, val, test => 8 1 1

# %%
unique_users = ratings['user'].unique()
unique_items = ratings['item'].unique()

# %%
user2id = {user: idx for idx, user in enumerate(unique_users)}
id2user = {idx: user for idx, user in enumerate(unique_users)}

item2id = {item: idx for idx, item in enumerate(unique_items)}
id2item = {idx: item for idx, item in enumerate(unique_items)}

ratings['user'] = ratings['user'].map(user2id)
ratings['item'] = ratings['item'].map(item2id)

ratings
# Out:
#        user  item  rating       time
# 0         0     0       3  881250949
# 1         1     1       3  891717742
# 2         2     2       1  878887116
# 3         3     3       2  880606923
# 4         4     4       1  886397596
# ...     ...   ...     ...        ...
# 99995   875   173       3  880175444
# 99996   708   247       5  879795543
# 99997    37  1004       1  874795795
# 99998    58   443       2  882399156
# 99999   304   506       3  879959583
#
# [100000 rows x 4 columns]

# %%
ratings.loc[:, 'rating'] = 1

# %%
ratings
# Out:
#        user  item  rating       time
# 0         0     0       1  881250949
# 1         1     1       1  891717742
# 2         2     2       1  878887116
# 3         3     3       1  880606923
# 4         4     4       1  886397596
# ...     ...   ...     ...        ...
# 99995   875   173       1  880175444
# 99996   708   247       1  879795543
# 99997    37  1004       1  874795795
# 99998    58   443       1  882399156
# 99999   304   506       1  879959583
#
# [100000 rows x 4 columns]

# %%
ratings_sorted = ratings.sort_values(by=['user', 'time'])

# %%
ratings_sorted
# Out:
#        user  item  rating       time
# 0         0     0       1  881250949
# 13733     0   289       1  881250949
# 78787     0   491       1  881250949
# 6910      0   380       1  881251021
# 25726     0   751       1  881251045
# ...     ...   ...     ...        ...
# 95587   942   141       1  875049038
# 68547   942   452       1  875049077
# 99006   942   672       1  875049077
# 84713   942    68       1  875049144
# 98516   942    24       1  875049144
#
# [100000 rows x 4 columns]

# %%
# 각 유저별로 train, validation, test 데이터로 분할 (8:1:1 비율)
train, temp = train_test_split(ratings_sorted, test_size=0.2, stratify=ratings_sorted['user'], random_state=42)
val, test = train_test_split(temp, test_size=0.5, stratify=temp['user'], random_state=42)

# %%
len(ratings_sorted[ratings_sorted['user']==1]), len(train[train['user']==1]), len(val[val['user']==1]), len(test[test['user']==1])
# Out:
# (92, 74, 9, 9)

# %% [markdown]
# 저장

# %%
import pickle

# %%
result = {
    "train": train,
    "val" : val,
    "test" : test,
    "all_items": all_movies,
    "user2id" : user2id,
    "id2user" : id2user,
    "item2id" : item2id,
    "id2item" : id2item,
}

# %%
with open('ml-100k_splited.pkl', 'wb') as f:
    pickle.dump(result, f)

# %% [markdown]
# negative sampling 예시

# %%
all_movies = ratings['item'].unique()

users, items, labels = [], [], []

user_item_set = set(zip(train['user'], train['item']))

num_neg = 4

for u, i in tqdm(user_item_set):
    users.append(u)
    items.append(i)
    labels.append(1)
    for _ in range(num_neg):
        neg_item = np.random.choice(all_movies)
        while (u, neg_item) in user_item_set:
            neg_item = np.random.choice(all_movies)
        users.append(u)
        items.append(neg_item)
        labels.append(0)
# Out:
# 100%|██████████| 80000/80000 [00:03<00:00, 23808.64it/s]

# %%
list(zip(users, items, labels))
# Out:
# [(476, 78, 1),
#  (476, 1088, 0),
#  (476, 650, 0),
#  (476, 1046, 0),
#  (476, 898, 0),
#  (192, 319, 1),
#  (192, 865, 0),
#  (192, 638, 0),
#  (192, 1011, 0),
#  (192, 1037, 0),
#  (782, 1316, 1),
#  (782, 724, 0),
#  (782, 654, 0),
#  (782, 1635, 0),
#  (782, 1382, 0),
#  (720, 438, 1),
#  (720, 59, 0),
#  (720, 645, 0),
#  (720, 733, 0),
#  (720, 388, 0),
#  (491, 386, 1),
#  (491, 1604, 0),
#  (491, 1577, 0),
#  (491, 1280, 0),
#  (491, 1377, 0),
#  (626, 22, 1),
#  (626, 748, 0),
#  (626, 1299, 0),
#  (626, 1317, 0),
#  (626, 931, 0),
#  (3, 797, 1),
#  (3, 381, 0),
#  (3, 484, 0),
#  (3, 344, 0),
#  (3, 665, 0),
#  (58, 504, 1),
#  (58, 1526, 0),
#  (58, 1131, 0),
#  (58, 1665, 0),
#  (58, 1158, 0),
#  (777, 191, 1),
#  (777, 1189, 0),
#  (777, 187, 0),
#  (777, 1130, 0),
#  (777, 1211, 0),
#  (89, 571, 1),
#  (89, 1121, 0),
#  (89, 258, 0),
#  (89, 1429, 0),
#  (89, 270, 0),
#  (143, 53, 1),
#  (143, 592, 0),
#  (143, 1493, 0),
#  (143, 514, 0),
#  (143, 960, 0),
#  (826, 83, 1),
#  (826, 1372, 0),
#  (826, 71, 0),
#  (826, 971, 0),
#  (826, 726, 0),
#  (927, 135, 1),
#  (927, 1223, 0),
#  (927, 1306, 0),
#  (927, 1671, 0),
#  (927, 228, 0),
#  (445, 391, 1),
#  (445, 604, 0),
#  (445, 385, 0),
#  (445, 528, 0),
#  (445, 324, 0),
#  (539, 26, 1),
#  (539, 23, 0),
#  (539, 931, 0),
#  (539, 1229, 0),
#  (539, 1097, 0),
#  (293, 751, 1),
#  (293, 1675, 0),
#  (293, 868, 0),
#  (293, 1068, 0),
#  (293, 536, 0),
#  (782, 161, 1),
#  (782, 1389, 0),
#  (782, 1610, 0),
#  (782, 170, 0),
#  (782, 1231, 0),
#  (453, 1383, 1),
#  (453, 792, 0),
#  (453, 1254, 0),
#  (453, 252, 0),
#  (453, 829, 0),
#  (881, 140, 1),
#  (881, 251, 0),
#  (881, 683, 0),
#  (881, 1565, 0),
#  (881, 1626, 0),
#  (313, 622, 1),
#  (313, 711, 0),
#  (313, 1449, 0),
#  (313, 1412, 0),
#  (313, 867, 0),
#  (404, 740, 1),
#  (404, 1295, 0),
#  (404, 1551, 0),
#  (404, 539, 0),
#  (404, 676, 0),
#  (252, 346, 1),
#  (252, 706, 0),
#  (252, 891, 0),
#  (252, 23, 0),
#  (252, 539, 0),
#  (752, 669, 1),
#  (752, 1432, 0),
#  (752, 1539, 0),
#  (752, 1555, 0),
#  (752, 667, 0),
#  (838, 443, 1),
#  (838, 736, 0),
#  (838, 1375, 0),
#  (838, 187, 0),
#  (838, 1225, 0),
#  (442, 443, 1),
#  (442, 589, 0),
#  (442, 1631, 0),
#  (442, 1648, 0),
#  (442, 1152, 0),
#  (402, 1044, 1),
#  (402, 1421, 0),
#  (402, 409, 0),
#  (402, 658, 0),
#  (402, 1248, 0),
#  (116, 458, 1),
#  (116, 1233, 0),
#  (116, 1509, 0),
#  (116, 1446, 0),
#  (116, 359, 0),
#  (501, 269, 1),
#  (501, 242, 0),
#  (501, 1170, 0),
#  (501, 1642, 0),
#  (501, 610, 0),
#  (248, 577, 1),
#  (248, 1499, 0),
#  (248, 1009, 0),
#  (248, 1116, 0),
#  (248, 547, 0),
#  (55, 182, 1),
#  (55, 486, 0),
#  (55, 817, 0),
#  (55, 617, 0),
#  (55, 479, 0),
#  (797, 38, 1),
#  (797, 665, 0),
#  (797, 705, 0),
#  (797, 493, 0),
#  (797, 1501, 0),
#  (492, 156, 1),
#  (492, 924, 0),
#  (492, 1326, 0),
#  (492, 1550, 0),
#  (492, 278, 0),
#  (205, 99, 1),
#  (205, 1347, 0),
#  (205, 652, 0),
#  (205, 806, 0),
#  (205, 692, 0),
#  (19, 875, 1),
#  (19, 1534, 0),
#  (19, 1183, 0),
#  (19, 715, 0),
#  (19, 246, 0),
#  (504, 166, 1),
#  (504, 1456, 0),
#  (504, 562, 0),
#  (504, 1547, 0),
#  (504, 1565, 0),
#  (751, 43, 1),
#  (751, 1404, 0),
#  (751, 958, 0),
#  (751, 161, 0),
#  (751, 1663, 0),
#  (11, 233, 1),
#  (11, 1136, 0),
#  (11, 212, 0),
#  (11, 696, 0),
#  (11, 611, 0),
#  (883, 162, 1),
#  (883, 677, 0),
#  (883, 1278, 0),
#  (883, 1129, 0),
#  (883, 197, 0),
#  (599, 403, 1),
#  (599, 819, 0),
#  (599, 1046, 0),
#  (599, 496, 0),
#  (599, 1032, 0),
#  (654, 110, 1),
#  (654, 1513, 0),
#  (654, 189, 0),
#  (654, 1602, 0),
#  (654, 1548, 0),
#  (310, 300, 1),
#  (310, 663, 0),
#  (310, 1615, 0),
#  (310, 1417, 0),
#  (310, 410, 0),
#  (318, 161, 1),
#  (318, 780, 0),
#  (318, 1673, 0),
#  (318, 1226, 0),
#  (318, 781, 0),
#  (10, 8, 1),
#  (10, 884, 0),
#  (10, 1661, 0),
#  (10, 1040, 0),
#  (10, 410, 0),
#  (557, 177, 1),
#  (557, 772, 0),
#  (557, 688, 0),
#  (557, 1252, 0),
#  (557, 367, 0),
#  (161, 177, 1),
#  (161, 440, 0),
#  (161, 1414, 0),
#  (161, 274, 0),
#  (161, 973, 0),
#  (120, 176, 1),
#  (120, 1229, 0),
#  (120, 1046, 0),
#  (120, 285, 0),
#  (120, 1573, 0),
#  (465, 588, 1),
#  (465, 1368, 0),
#  (465, 901, 0),
#  (465, 1607, 0),
#  (465, 532, 0),
#  (64, 244, 1),
#  (64, 359, 0),
#  (64, 225, 0),
#  (64, 12, 0),
#  (64, 126, 0),
#  (181, 829, 1),
#  (181, 721, 0),
#  (181, 1127, 0),
#  (181, 1603, 0),
#  (181, 775, 0),
#  (804, 54, 1),
#  (804, 1391, 0),
#  (804, 629, 0),
#  (804, 1201, 0),
#  (804, 786, 0),
#  (845, 809, 1),
#  (845, 1568, 0),
#  (845, 1213, 0),
#  (845, 723, 0),
#  (845, 1605, 0),
#  (499, 172, 1),
#  (499, 269, 0),
#  (499, 346, 0),
#  (499, 1180, 0),
#  (499, 839, 0),
#  (559, 223, 1),
#  (559, 871, 0),
#  (559, 1491, 0),
#  (559, 1231, 0),
#  (559, 1431, 0),
#  (311, 121, 1),
#  (311, 1641, 0),
#  (311, 42, 0),
#  (311, 367, 0),
#  (311, 804, 0),
#  (428, 1460, 1),
#  (428, 769, 0),
#  (428, 568, 0),
#  (428, 535, 0),
#  (428, 1465, 0),
#  (402, 239, 1),
#  (402, 1050, 0),
#  (402, 1652, 0),
#  (402, 443, 0),
#  (402, 1111, 0),
#  (118, 480, 1),
#  (118, 110, 0),
#  (118, 295, 0),
#  (118, 1645, 0),
#  (118, 1493, 0),
#  (365, 357, 1),
#  (365, 865, 0),
#  (365, 551, 0),
#  (365, 328, 0),
#  (365, 681, 0),
#  (24, 64, 1),
#  (24, 1573, 0),
#  (24, 1, 0),
#  (24, 1218, 0),
#  (24, 1149, 0),
#  (860, 336, 1),
#  (860, 1020, 0),
#  (860, 1048, 0),
#  (860, 1201, 0),
#  (860, 1062, 0),
#  (765, 1230, 1),
#  (765, 300, 0),
#  (765, 1335, 0),
#  (765, 169, 0),
#  (765, 1377, 0),
#  (80, 1127, 1),
#  (80, 1068, 0),
#  (80, 613, 0),
#  (80, 234, 0),
#  (80, 1154, 0),
#  (18, 249, 1),
#  (18, 188, 0),
#  (18, 642, 0),
#  (18, 44, 0),
#  (18, 1418, 0),
#  (325, 177, 1),
#  (325, 1296, 0),
#  (325, 424, 0),
#  (325, 1097, 0),
#  (325, 538, 0),
#  (366, 178, 1),
#  (366, 295, 0),
#  (366, 1073, 0),
#  (366, 960, 0),
#  (366, 328, 0),
#  (41, 418, 1),
#  (41, 727, 0),
#  (41, 1232, 0),
#  (41, 742, 0),
#  (41, 1453, 0),
#  (77, 75, 1),
#  (77, 953, 0),
#  (77, 1583, 0),
#  (77, 1201, 0),
#  (77, 235, 0),
#  (760, 105, 1),
#  (760, 322, 0),
#  (760, 297, 0),
#  (760, 201, 0),
#  (760, 1281, 0),
#  (913, 347, 1),
#  (913, 1216, 0),
#  (913, 1430, 0),
#  (913, 1099, 0),
#  (913, 1394, 0),
#  (176, 54, 1),
#  (176, 8, 0),
#  (176, 1088, 0),
#  (176, 1126, 0),
#  (176, 1440, 0),
#  (603, 121, 1),
#  (603, 1441, 0),
#  (603, 1316, 0),
#  (603, 47, 0),
#  (603, 1179, 0),
#  (723, 223, 1),
#  (723, 243, 0),
#  (723, 382, 0),
#  (723, 36, 0),
#  (723, 85, 0),
#  (76, 604, 1),
#  (76, 893, 0),
#  (76, 1481, 0),
#  (76, 660, 0),
#  (76, 1108, 0),
#  (38, 120, 1),
#  (38, 372, 0),
#  (38, 268, 0),
#  (38, 1350, 0),
#  (38, 944, 0),
#  (607, 240, 1),
#  (607, 1601, 0),
#  (607, 551, 0),
#  (607, 1131, 0),
#  (607, 23, 0),
#  (37, 649, 1),
#  (37, 1291, 0),
#  (37, 1523, 0),
#  (37, 1500, 0),
#  (37, 1321, 0),
#  (195, 1235, 1),
#  (195, 124, 0),
#  (195, 887, 0),
#  (195, 913, 0),
#  (195, 905, 0),
#  (133, 357, 1),
#  (133, 1369, 0),
#  (133, 574, 0),
#  (133, 805, 0),
#  (133, 1620, 0),
#  (70, 8, 1),
#  (70, 1430, 0),
#  (70, 842, 0),
#  (70, 1284, 0),
#  (70, 34, 0),
#  (531, 403, 1),
#  (531, 1409, 0),
#  (531, 664, 0),
#  (531, 452, 0),
#  (531, 1069, 0),
#  (369, 75, 1),
#  (369, 936, 0),
#  (369, 1555, 0),
#  (369, 982, 0),
#  (369, 1539, 0),
#  (90, 660, 1),
#  (90, 1000, 0),
#  (90, 1173, 0),
#  (90, 164, 0),
#  (90, 1421, 0),
#  (864, 54, 1),
#  (864, 992, 0),
#  (864, 545, 0),
#  (864, 190, 0),
#  (864, 1325, 0),
#  (428, 655, 1),
#  (428, 1502, 0),
#  (428, 1320, 0),
#  (428, 1565, 0),
#  (428, 789, 0),
#  (376, 465, 1),
#  (376, 357, 0),
#  (376, 1320, 0),
#  (376, 1552, 0),
#  (376, 1585, 0),
#  (711, 189, 1),
#  (711, 1181, 0),
#  (711, 489, 0),
#  (711, 113, 0),
#  (711, 278, 0),
#  (769, 167, 1),
#  (769, 1281, 0),
#  (769, 295, 0),
#  (769, 1359, 0),
#  (769, 1025, 0),
#  (765, 425, 1),
#  (765, 1599, 0),
#  (765, 1136, 0),
#  (765, 398, 0),
#  (765, 125, 0),
#  (835, 1164, 1),
#  (835, 561, 0),
#  (835, 1027, 0),
#  (835, 737, 0),
#  (835, 108, 0),
#  (861, 133, 1),
#  (861, 1526, 0),
#  (861, 1643, 0),
#  (861, 1574, 0),
#  (861, 293, 0),
#  (489, 527, 1),
#  (489, 827, 0),
#  (489, 685, 0),
#  (489, 744, 0),
#  (489, 235, 0),
#  (88, 183, 1),
#  (88, 556, 0),
#  (88, 812, 0),
#  (88, 999, 0),
#  (88, 454, 0),
#  (921, 938, 1),
#  (921, 1065, 0),
#  (921, 469, 0),
#  (921, 1534, 0),
#  (921, 794, 0),
#  (637, 1179, 1),
#  (637, 891, 0),
#  (637, 1064, 0),
#  (637, 632, 0),
#  (637, 609, 0),
#  (859, 60, 1),
#  (859, 977, 0),
#  (859, 639, 0),
#  (859, 1046, 0),
#  (859, 451, 0),
#  (473, 24, 1),
#  (473, 565, 0),
#  (473, 1388, 0),
#  (473, 574, 0),
#  (473, 426, 0),
#  (764, 173, 1),
#  (764, 1196, 0),
#  (764, 262, 0),
#  (764, 56, 0),
#  (764, 220, 0),
#  (638, 1000, 1),
#  (638, 1345, 0),
#  (638, 1553, 0),
#  (638, 1221, 0),
#  (638, 1035, 0),
#  (191, 311, 1),
#  (191, 648, 0),
#  (191, 496, 0),
#  (191, 981, 0),
#  (191, 495, 0),
#  (820, 482, 1),
#  (820, 556, 0),
#  (820, 258, 0),
#  (820, 1673, 0),
#  (820, 419, 0),
#  (378, 137, 1),
#  (378, 752, 0),
#  (378, 747, 0),
#  (378, 344, 0),
#  (378, 1588, 0),
#  (875, 189, 1),
#  (875, 481, 0),
#  (875, 878, 0),
#  (875, 879, 0),
#  (875, 513, 0),
#  (570, 307, 1),
#  (570, 1531, 0),
#  (570, 791, 0),
#  (570, 1555, 0),
#  (570, 923, 0),
#  (914, 117, 1),
#  (914, 649, 0),
#  (914, 172, 0),
#  (914, 1087, 0),
#  (914, 1348, 0),
#  (589, 357, 1),
#  (589, 441, 0),
#  (589, 1501, 0),
#  (589, 394, 0),
#  (589, 142, 0),
#  (341, 255, 1),
#  (341, 1506, 0),
#  (341, 1236, 0),
#  (341, 353, 0),
#  (341, 1049, 0),
#  (650, 1010, 1),
#  (650, 577, 0),
#  (650, 742, 0),
#  (650, 1163, 0),
#  (650, 414, 0),
#  (627, 60, 1),
#  (627, 222, 0),
#  (627, 80, 0),
#  (627, 830, 0),
#  (627, 1441, 0),
#  (243, 851, 1),
#  (243, 1542, 0),
#  (243, 1409, 0),
#  (243, 445, 0),
#  (243, 152, 0),
#  (3, 610, 1),
#  (3, 615, 0),
#  (3, 162, 0),
#  (3, 320, 0),
#  (3, 818, 0),
#  (58, 317, 1),
#  (58, 1438, 0),
#  (58, 28, 0),
#  (58, 1071, 0),
#  (58, 1350, 0),
#  (834, 538, 1),
#  (834, 1321, 0),
#  (834, 1152, 0),
#  (834, 1312, 0),
#  (834, 1151, 0),
#  (555, 1123, 1),
#  (555, 1166, 0),
#  (555, 995, 0),
#  (555, 946, 0),
#  (555, 1327, 0),
#  (144, 91, 1),
#  (144, 511, 0),
#  (144, 1305, 0),
#  (144, 345, 0),
#  (144, 1453, 0),
#  (295, 260, 1),
#  (295, 1544, 0),
#  (295, 1675, 0),
#  (295, 946, 0),
#  (295, 843, 0),
#  (448, 502, 1),
#  (448, 792, 0),
#  (448, 147, 0),
#  (448, 726, 0),
#  (448, 986, 0),
#  (47, 158, 1),
#  (47, 1195, 0),
#  (47, 35, 0),
#  (47, 634, 0),
#  (47, 648, 0),
#  (797, 656, 1),
#  (797, 1125, 0),
#  (797, 643, 0),
#  (797, 737, 0),
#  (797, 676, 0),
#  (107, 209, 1),
#  (107, 297, 0),
#  (107, 454, 0),
#  (107, 297, 0),
#  (107, 933, 0),
#  (52, 502, 1),
#  (52, 825, 0),
#  (52, 41, 0),
#  (52, 554, 0),
#  (52, 615, 0),
#  (831, 240, 1),
#  (831, 515, 0),
#  (831, 561, 0),
#  (831, 1067, 0),
#  (831, 708, 0),
#  (650, 1360, 1),
#  (650, 351, 0),
#  (650, 1150, 0),
#  (650, 1499, 0),
#  (650, 1432, 0),
#  (263, 722, 1),
#  (263, 642, 0),
#  (263, 505, 0),
#  (263, 584, 0),
#  (263, 237, 0),
#  (51, 277, 1),
#  (51, 1091, 0),
#  (51, 1180, 0),
#  (51, 1594, 0),
#  (51, 566, 0),
#  (734, 307, 1),
#  (734, 675, 0),
#  (734, 1284, 0),
#  (734, 992, 0),
#  (734, 366, 0),
#  (887, 549, 1),
#  (887, 889, 0),
#  (887, 1201, 0),
#  (887, 584, 0),
#  (887, 1130, 0),
#  (491, 549, 1),
#  (491, 1246, 0),
#  (491, 53, 0),
#  (491, 574, 0),
#  (491, 1602, 0),
#  (546, 256, 1),
#  (546, 132, 0),
#  (546, 973, 0),
#  (546, 1308, 0),
#  (546, 1295, 0),
#  (257, 153, 1),
#  (257, 749, 0),
#  (257, 1642, 0),
#  (257, 1232, 0),
#  (257, 24, 0),
#  (205, 717, 1),
#  (205, 1538, 0),
#  (205, 461, 0),
#  (205, 1176, 0),
#  (205, 1004, 0),
#  (850, 1421, 1),
#  (850, 292, 0),
#  (850, 969, 0),
#  (850, 500, 0),
#  (850, 1680, 0),
#  (793, 887, 1),
#  (793, 1094, 0),
#  (793, 984, 0),
#  (793, 1486, 0),
#  (793, 445, 0),
#  (163, 491, 1),
#  (163, 817, 0),
#  (163, 1122, 0),
#  (163, 444, 0),
#  (163, 604, 0),
#  (9, 24, 1),
#  (9, 51, 0),
#  (9, 1280, 0),
#  (9, 946, 0),
#  (9, 102, 0),
#  (695, 729, 1),
#  (695, 170, 0),
#  (695, 921, 0),
#  (695, 1118, 0),
#  (695, 44, 0),
#  (748, 363, 1),
#  (748, 89, 0),
#  (748, 571, 0),
#  (748, 1004, 0),
#  (748, 1361, 0),
#  (63, 260, 1),
#  (63, 287, 0),
#  (63, 1437, 0),
#  (63, 276, 0),
#  (63, 662, 0),
#  (692, 431, 1),
#  (692, 429, 0),
#  (692, 1276, 0),
#  (692, 1493, 0),
#  (692, 1170, 0),
#  (465, 1206, 1),
#  (465, 1324, 0),
#  (465, 684, 0),
#  (465, 704, 0),
#  (465, 327, 0),
#  (499, 790, 1),
#  (499, 1413, 0),
#  (499, 1425, 0),
#  (499, 809, 0),
#  (499, 651, 0),
#  (442, 256, 1),
#  (442, 1468, 0),
#  (442, 1098, 0),
#  (442, 992, 0),
#  (442, 422, 0),
#  (158, 497, 1),
#  (158, 1027, 0),
#  (158, 1037, 0),
#  (158, 1171, 0),
#  (158, 1056, 0),
#  (402, 857, 1),
#  (402, 843, 0),
#  (402, 1479, 0),
#  (402, 1378, 0),
#  (402, 418, 0),
#  (405, 374, 1),
#  (405, 1216, 0),
#  (405, 1621, 0),
#  (405, 1316, 0),
#  (405, 874, 0),
#  (837, 31, 1),
#  (837, 340, 0),
#  (837, 53, 0),
#  (837, 1456, 0),
#  (837, 1160, 0),
#  (214, 806, 1),
#  (214, 1563, 0),
#  (214, 898, 0),
#  (214, 74, 0),
#  (214, 1198, 0),
#  (892, 492, 1),
#  (892, 1526, 0),
#  (892, 1575, 0),
#  (892, 1491, 0),
#  (892, 672, 0),
#  (501, 82, 1),
#  (501, 415, 0),
#  (501, 464, 0),
#  (501, 163, 0),
#  (501, 1551, 0),
#  (649, 734, 1),
#  (649, 518, 0),
#  (649, 1632, 0),
#  (649, 1226, 0),
#  (649, 1032, 0),
#  (248, 390, 1),
#  (248, 1573, 0),
#  (248, 1444, 0),
#  (248, 1158, 0),
#  (248, 1503, 0),
#  (456, 339, 1),
#  (456, 1242, 0),
#  (456, 1353, 0),
#  (456, 1290, 0),
#  (456, 1590, 0),
#  (646, 436, 1),
#  (646, 318, 0),
#  (646, 112, 0),
#  (646, 613, 0),
#  (646, 11, 0),
#  (20, 159, 1),
#  (20, 274, 0),
#  (20, 501, 0),
#  (20, 125, 0),
#  (20, 474, 0),
#  (856, 431, 1),
#  (856, 460, 0),
#  (856, 223, 0),
#  (856, 717, 0),
#  (856, 1587, 0),
#  (116, 621, 1),
#  (116, 116, 0),
#  (116, 302, 0),
#  (116, 1142, 0),
#  (116, 1621, 0),
#  (892, 842, 1),
#  (892, 1560, 0),
#  (892, 1637, 0),
#  (892, 194, 0),
#  (892, 1529, 0),
#  (694, 103, 1),
#  (694, 1323, 0),
#  (694, 1112, 0),
#  (694, 797, 0),
#  (694, 812, 0),
#  (35, 1221, 1),
#  (35, 53, 0),
#  (35, 1242, 0),
#  (35, 1037, 0),
#  (35, 1580, 0),
#  (19, 688, 1),
#  (19, 1261, 0),
#  (19, 1656, 0),
#  (19, 1128, 0),
#  (19, 928, 0),
#  (358, 154, 1),
#  (358, 35, 0),
#  (358, 1678, 0),
#  (358, 956, 0),
#  (358, 99, 0),
#  (110, 52, 1),
#  (110, 435, 0),
#  (110, 61, 0),
#  (110, 483, 0),
#  (110, 1587, 0),
#  (886, 273, 1),
#  (886, 1045, 0),
#  (886, 1607, 0),
#  (886, 1640, 0),
#  (886, 1236, 0),
#  (793, 82, 1),
#  (793, 1374, 0),
#  (793, 233, 0),
#  (793, 893, 0),
#  (793, 1573, 0),
#  (607, 858, 1),
#  (607, 1484, 0),
#  (607, 1322, 0),
#  (607, 550, 0),
#  (607, 1311, 0),
#  (412, 390, 1),
#  (412, 1102, 0),
#  (412, 1266, 0),
#  (412, 654, 0),
#  (412, 882, 0),
#  (71, 97, 1),
#  (71, 954, 0),
#  (71, 1265, 0),
#  (71, 989, 0),
#  (71, 618, 0),
#  (310, 113, 1),
#  (310, 966, 0),
#  (310, 1294, 0),
#  (310, 1574, 0),
#  (310, 270, 0),
#  (375, 508, 1),
#  (375, 290, 0),
#  (375, 150, 0),
#  (375, 1228, 0),
#  (375, 652, 0),
#  (26, 354, 1),
#  (26, 681, 0),
#  (26, 792, 0),
#  (26, 1111, 0),
#  (26, 1348, 0),
#  (937, 211, 1),
#  (937, 948, 0),
#  (937, 56, 0),
#  (937, 521, 0),
#  (937, 1388, 0),
#  (23, 56, 1),
#  (23, 1133, 0),
#  (23, 1664, 0),
#  (23, 1489, 0),
#  (23, 1132, 0),
#  (413, 211, 1),
#  (413, 1198, 0),
#  (413, 688, 0),
#  (413, 1176, 0),
#  (413, 187, 0),
#  (845, 622, 1),
#  (845, 675, 0),
#  (845, 1629, 0),
#  (845, 319, 0),
#  (845, 1049, 0),
#  (64, 57, 1),
#  (64, 708, 0),
#  (64, 983, 0),
#  (64, 215, 0),
#  (64, 1062, 0),
#  (129, 452, 1),
#  (129, 1623, 0),
#  (129, 137, 0),
#  (129, 1493, 0),
#  (129, 684, 0),
#  (27, 175, 1),
#  (27, 1552, 0),
#  (27, 195, 0),
#  (27, 927, 0),
#  (27, 1122, 0),
#  (402, 52, 1),
#  (402, 1465, 0),
#  (402, 1411, 0),
#  (402, 958, 0),
#  (402, 542, 0),
#  (426, 446, 1),
#  (426, 1528, 0),
#  (426, 851, 0),
#  (426, 432, 0),
#  (426, 1295, 0),
#  (897, 31, 1),
#  (897, 1339, 0),
#  (897, 811, 0),
#  (897, 1301, 0),
#  (897, 441, 0),
#  (654, 273, 1),
#  (654, 1491, 0),
#  (654, 731, 0),
#  (654, 1233, 0),
#  (654, 66, 0),
#  (573, 873, 1),
#  (573, 1660, 0),
#  (573, 1051, 0),
#  (573, 460, 0),
#  (573, 542, 0),
#  (516, 339, 1),
#  (516, 144, 0),
#  (516, 1289, 0),
#  (516, 1082, 0),
#  (516, 195, 0),
#  (172, 529, 1),
#  (172, 115, 0),
#  (172, 649, 0),
#  (172, 905, 0),
#  (172, 714, 0),
#  (526, 1027, 1),
#  (526, 1537, 0),
#  (526, 1122, 0),
#  (526, 56, 0),
#  (526, 1637, 0),
#  (180, 390, 1),
#  (180, 725, 0),
#  (180, 28, 0),
#  (180, 679, 0),
#  (180, 301, 0),
#  (328, 288, 1),
#  (328, 1363, 0),
#  (328, 683, 0),
#  (328, 1473, 0),
#  (328, 673, 0),
#  (367, 216, 1),
#  (367, 671, 0),
#  (367, 331, 0),
#  (367, 1225, 0),
#  (367, 1295, 0),
#  (804, 217, 1),
#  (804, 612, 0),
#  (804, 1474, 0),
#  (804, 289, 0),
#  (804, 1355, 0),
#  (88, 801, 1),
#  (88, 114, 0),
#  (88, 1401, 0),
#  (88, 1404, 0),
#  (88, 58, 0),
#  (231, 355, 1),
#  (231, 1481, 0),
#  (231, 1048, 0),
#  (231, 1002, 0),
#  (231, 1501, 0),
#  (802, 144, 1),
#  (802, 759, 0),
#  (802, 1239, 0),
#  (802, 789, 0),
#  (802, 1666, 0),
#  (421, 452, 1),
#  (421, 832, 0),
#  (421, 673, 0),
#  (421, 1485, 0),
#  (421, 490, 0),
#  (238, 745, 1),
#  (238, 994, 0),
#  (238, 1257, 0),
#  (238, 1235, 0),
#  (238, 370, 0),
#  (608, 278, 1),
#  (608, 1576, 0),
#  (608, 1201, 0),
#  (608, 1321, 0),
#  (608, 312, 0),
#  (35, 416, 1),
#  (35, 1211, 0),
#  (35, 746, 0),
#  (35, 1521, 0),
#  (35, 848, 0),
#  (379, 226, 1),
#  (379, 625, 0),
#  (379, 106, 0),
#  (379, 631, 0),
#  (379, 447, 0),
#  (37, 462, 1),
#  (37, 1210, 0),
#  (37, 1628, 0),
#  (37, 1142, 0),
#  (37, 1619, 0),
#  (138, 514, 1),
#  (138, 1070, 0),
#  (138, 725, 0),
#  (138, 1357, 0),
#  (138, 109, 0),
#  (630, 976, 1),
#  (630, 797, 0),
#  (630, 1508, 0),
#  (630, 1261, 0),
#  (630, 794, 0),
#  (661, 289, 1),
#  (661, 1643, 0),
#  (661, 1654, 0),
#  (661, 193, 0),
#  (661, 1628, 0),
#  ...]
