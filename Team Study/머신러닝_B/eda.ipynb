# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def label_encode_string_columns(df):
    label_encoder = LabelEncoder()
    for col in df.columns:
        if df[col].dtype == 'object':
            df[col] = label_encoder.fit_transform(df[col])
    return df

# %%
def plot_heatmap(data, columns):
    correlation_matrix = data[columns].corr()
    plt.figure()
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt=".2f")
    plt.title('Feature Correlation Heatmap')
    plt.show(block=False)

# %%
def plot_feature(data, column):
    plt.figure()
    plt.scatter(np.arange(len(data)), data[column], s=0.1, alpha=0.8)
    plt.title(f'Plot {column}')
    plt.xlabel('Index')
    plt.ylabel(column)
    plt.grid(True)
    plt.show(block=False)

# %%
def plot_feature_distribution(data, column):
    plt.figure()
    sns.kdeplot(data[column], fill=True)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Density')
    plt.grid(True)
    plt.show(block=False)

# %%
def plot_feature_to_target(data, column, target):
    plt.figure()
    plt.scatter(data[column], data[target], c='blue', s=0.2, marker='o')
    plt.title(f'Feature({column}) to Target({target})')
    plt.xlabel(column)
    plt.ylabel('target')
    plt.grid(True)
    plt.show(block=False)

# %%
def heatmap(data):
    correlation_matrix = data.corr()
    plt.figure()
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt=".2f")
    plt.title('Feature Correlation Heatmap')
    plt.show()

# %%
def feature_graph(data, column_name):
    plt.figure()
    plt.scatter(np.arange(len(data)), data, alpha=0.8)
    plt.title(f'Distribution of {column_name} in Coordinate Space')
    plt.xlabel('Index')
    plt.ylabel(column_name)
    plt.grid(True)
    plt.show()

# %%
def compare_two_column(data1, data2, data1_name, data2_name):
    plt.figure()
    plt.scatter(data1, data2, c='blue', marker='o')
    plt.title(f'Scatter Plot of {data1_name} & {data2_name}')
    plt.xlabel(f'{data1_name}')
    plt.ylabel(f'{data2_name}')
    plt.grid(True)
    plt.show()

# %%
def plot_func(df, column, target):
    count_df = df.groupby([column, target]).size().unstack(fill_value=0)
    count_df = count_df.div(count_df.sum(axis=1), axis=0)
    count_df.plot(kind='bar', stacked=True, color=['salmon', 'skyblue'], figsize=(8, 4))
    plt.xlabel(f'{column}')
    plt.ylabel('Proportion')
    plt.title(f'Proportion of Target by {column}')
    plt.legend(title='Target', loc='upper right')
    plt.ylim(0, 1)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    for i in range(count_df.shape[0]):
        for j in range(count_df.shape[1]):
            plt.text(i, count_df.iloc[i, j] / 2 + count_df.iloc[i, :j].sum(), f"{count_df.iloc[i, j]:.2f}", ha='center', color='black')
    plt.show()

# %%
df_baedang = pd.read_csv('open (1)/NH_CONTEST_DATA_HISTORICAL_DIVIDEND.csv')

# %%
df_baedang
# Out:
#       etf_tck_cd   ediv_dt  ddn_amt  aed_stkp_ddn_amt ddn_bse_dt  ddn_pym_dt  \
# 0           AAON  20230608     0.12              0.08   20230609    20230630
# 1           AAON  20240315     0.08              0.08   20240318    20240329
# 2           AAON  20230907     0.08              0.08   20230908    20230929
# 3           AAON  20230310     0.12              0.08   20230313    20230331
# 4           AAON  20221125     0.24              0.16   20221128    20221216
# ...          ...       ...      ...               ...        ...         ...
# 12852       ZION  20230816     0.41              0.41   20230817    20230824
# 12853       ZION  20240214     0.41              0.41   20240215    20240222
# 12854       ZION  20230215     0.41              0.41   20230216    20230223
# 12855       ZION  20230517     0.41              0.41   20230518    20230525
# 12856       ZION  20221109     0.41              0.41   20221110    20221117
#
#          pba_dt ddn_pym_fcy_cd
# 0      20230518      Quarterly
# 1      20240301      Quarterly
# 2      20230818      Quarterly
# 3      20230301      Quarterly
# 4      20221108     SemiAnnual
# ...         ...            ...
# 12852  20230728      Quarterly
# 12853  20240202      Quarterly
# 12854  20230127      Quarterly
# 12855  20230505      Quarterly
# 12856  20221028      Quarterly
#
# [12857 rows x 8 columns]

# %%
df_peopledata = pd.read_csv('open (1)/NH_CONTEST_NHDATA_CUS_TP_IFO.csv')

# %%
df_peopledata
# Out:
#            bse_dt    tck_iem_cd  cus_cgr_llf_cd  cus_cgr_mlf_cd  \
# 0        20240826  AAL                        2              22
# 1        20240826  AAL                        2              25
# 2        20240826  AAL                        2              21
# 3        20240826  AAL                        2              23
# 4        20240816  AAL                        2              21
# ...           ...           ...             ...             ...
# 1194995  20240612  ZS                         2              24
# 1194996  20240529  ZS                         3              31
# 1194997  20240819  ZS                         2              21
# 1194998  20240819  ZS                         2              23
# 1194999  20240819  ZS                         2              24
#
#          cus_cgr_act_cnt_rt  cus_cgr_ivs_rt
# 0                   37.2608         37.5675
# 1                    4.8405         11.8565
# 2                   21.4259         11.5923
# 3                   23.9400         21.7531
# 4                   21.4740         11.7051
# ...                     ...             ...
# 1194995             25.3165         23.7650
# 1194996             36.8421         11.7457
# 1194997             14.7059          7.2295
# 1194998             28.8235         25.3286
# 1194999             21.7647         17.5430
#
# [1195000 rows x 6 columns]

# %%
df_baedang['etf_tck_cd'].value_counts()
# Out:
# etf_tck_cd
# QYLD     25
# XYLD     25
# RYLD     25
# EFC      25
# DX       24
#          ..
# ARHS      1
# CONL      1
# GOOGL     1
# FIZZ      1
# AIRS      1
# Name: count, Length: 1631, dtype: int64

# %%
df_info = pd.read_csv('open (1)/NH_CONTEST_DATA_ETF_HOLDINGS.csv', encoding='cp949')

# %%
df_info
# Out:
#       etf_tck_cd tck_iem_cd     mkt_vlu  \
# 0           AAPB       AAPL    36858666
# 1           AAPB        USD    18337384
# 2           AMDL        USD     3257693
# 3           AMDL        AMD     6530355
# 4           CLOU       TWLO    15400502
# ...          ...        ...         ...
# 40714        TMF          -  2981494930
# 40715        TMF          -     3838866
# 40716        TMF          -   693619858
# 40717        TMF          -  1146532591
# 40718        TMF          -   741422980
#
#                                  fc_sec_eng_nm  fc_sec_krl_nm   stk_qty  \
# 0                                         AAPL             애플    215737
# 1                                   US Dollars  프로셰어즈 울트라 반도체         0
# 2                                   US Dollars  프로셰어즈 울트라 반도체         0
# 3                                          AMD           에이엠디     36558
# 4                               TWILIO INC - A           트윌리오    254933
# ...                                        ...            ...       ...
# 40714  ISHARES 20+ YEAR TREASURY BOND ETF SWAP              -  31278797
# 40715       DREYFUS TRSRY SECURITIES CASH MGMT              -         0
# 40716           GOLDMAN FINL SQ TRSRY INST 506              -         0
# 40717                DREYFUS GOVT CASH MAN INS              -         0
# 40718  ISHARES 20+ YEAR TREASURY BOND ETF SWAP              -   7778252
#
#        wht_pct sec_tp
# 0       66.778     ST
# 1       33.222     EF
# 2       33.282     EF
# 3       66.718     ST
# 4        4.266     ST
# ...        ...    ...
# 40714   14.837      -
# 40715    0.019      -
# 40716    3.452      -
# 40717    5.706      -
# 40718    3.690      -
#
# [40719 rows x 8 columns]

# %%
df_sample = pd.read_csv('open (1)/NH_CONTEST_NW_FC_STK_IEM_IFO.csv', encoding='cp949')

# %%
df_sample
# Out:
#      tck_iem_cd                                      fc_sec_krl_nm  \
# 0            AA  알코아                                           ...
# 1           AAL  아메리칸 에어라인스 그룹                                 ...
# 2           AAN  Aaron's Company                               ...
# 3          AAOI  어플라이드 옵토일렉트로닉스                                ...
# 4          AAON  에이에이온                                         ...
# ...         ...                                                ...
# 3091       ZURA  Zura Bio                                      ...
# 3092       ZVRA  Zevra                                         ...
# 3093        ZWS  Zurn Elkay Wtr                                ...
# 3094       ZYME  Zymeworks                                     ...
# 3095       ZYXI  Zynex                                         ...
#
#                                           fc_sec_eng_nm stk_etf_dit_cd  \
# 0     Alcoa Corp                                    ...             주식
# 1     American Airline                              ...             주식
# 2     Aaron's Company                               ...             주식
# 3     AOI                                           ...             주식
# 4     AAON                                          ...             주식
# ...                                                 ...            ...
# 3091  Zura Bio                                      ...             주식
# 3092  Zevra                                         ...             주식
# 3093  Zurn Elkay Wtr                                ...             주식
# 3094  Zymeworks                                     ...             주식
# 3095  Zynex                                         ...             주식
#
#       ltg_tot_stk_qty fc_mkt_dit_cd  \
# 0           258340140          NYSE
# 1           656703913          NASD
# 2            31550767          NYSE
# 3            42644441          NASD
# 4            81013148          NASD
# ...               ...           ...
# 3091         63207088          NASD
# 3092         52617789          NASD
# 3093        170928495          NYSE
# 3094         71618027          NASD
# 3095         31742522          NASD
#
#                                                  co_adr  \
# 0     201 Isabella Street, Suite 500   PITTSBURGH PA...
# 1     1 Skyview Drive   FORT WORTH TX 76155 United S...
# 2     400 Galleria Parkway Se, Suite 300   ATLANTA G...
# 3     13139 Jess Pirtle Blvd   SUGAR LAND TX 77478 U...
# 4     2425 South Yukon Ave.   TULSA OK 74107 United ...
# ...                                                 ...
# 3091  4225 Executive Square, Suite - 600   SAN DIEGO...
# 3092  1180 CELEBRATION BOULEVARD, SUITE 103   CELEBR...
# 3093  511 West Freshwater Way   MILWAUKEE WI 53204 U...
# 3094  108 Patriot Drive, Suite A   MIDDLETOWN DE 197...
# 3095  9655 Maroon Circle   ENGLEWOOD CO 80112 United...
#
#                                     web_adr  \
# 0      https://www.alcoa.com/global/en/home
# 1     https://americanairlines.gcs-web.com/
# 2              https://investor.aarons.com/
# 3                       https://ao-inc.com/
# 4                     https://www.aaon.com/
# ...                                     ...
# 3091                   https://zurabio.com/
# 3092                     https://zevra.com/
# 3093                https://zurn-elkay.com/
# 3094             https://www.zymeworks.com/
# 3095                 https://www.zynex.com/
#
#                                    btp_cfc_nm             ceo_nm  \
# 0                              Aluminum (NEC)   William Oplinger
# 1                           Regional Airlines        Robert Isom
# 2                            Consumer Leasing      Stephen Olsen
# 3                       Electronic Components    Chih-Hsiang Lin
# 4     Heating, Ventilation & Air Conditioning      Matt Tobolski
# ...                                       ...                ...
# 3091                    Bio Therapeutic Drugs     Robert Lisicki
# 3092   Proprietary & Advanced Pharmaceuticals     Neil Mcfarlane
# 3093   Construction Supplies & Fixtures (NEC)         Todd Adams
# 3094                    Bio Therapeutic Drugs  Kenneth Galbraith
# 3095  Advanced Medical Equipment & Technology   Thomas Sandgaard
#
#                                         eng_utk_otl_cts       ser_cfc_nm  \
# 0     Alcoa Corporation is a vertically integrated a...  Basic Materials
# 1     American Airlines Group Inc. is a holding comp...      Industrials
# 2     The Aaron?? Company, Inc. is a technology-enab...      Industrials
# 3     Applied Optoelectronics, Inc. is a vertically ...       Technology
# 4     AAON, Inc. is a producer of heating, ventilati...      Industrials
# ...                                                 ...              ...
# 3091  Zura Bio Limited is a clinical-stage, multi-as...       Healthcare
# 3092  Zevra Therapeutics, Inc. is a rare disease com...       Healthcare
# 3093  Zurn Elkay Water Solutions Corp is a pure-play...      Industrials
# 3094  Zymeworks Inc. is a global biotechnology compa...       Healthcare
# 3095  Zynex, Inc. develops, manufactures, markets an...       Healthcare
#
#                               ids_nm  mkt_pr_tot_amt
# 0                           Aluminum         8928.24
# 1                           Airlines         6711.51
# 2          Rental & Leasing Services          318.03
# 3            Communication Equipment          393.42
# 4      Building Products & Equipment         7605.92
# ...                              ...             ...
# 3091                   Biotechnology          255.99
# 3092                   Biotechnology          372.01
# 3093  Pollution & Treatment Controls         5485.10
# 3094                   Biotechnology          819.89
# 3095            Medical Distribution          265.05
#
# [3096 rows x 14 columns]
