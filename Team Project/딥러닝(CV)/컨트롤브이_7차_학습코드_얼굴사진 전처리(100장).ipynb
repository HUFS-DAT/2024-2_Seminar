# %% [markdown]
# ## Face Alignment & Normalization (내 사진 100장)

# %%
import numpy as np
import cv2

def rect_to_bb(rect):
	# take a bounding predicted by dlib and convert it
	# to the format (x, y, w, h) as we would normally do
	# with OpenCV
	x = rect.left()
	y = rect.top()
	w = rect.right() - x
	h = rect.bottom() - y
	# return a tuple of (x, y, w, h)
	return (x, y, w, h)

def shape_to_np(shape, dtype="int"):
	# initialize the list of (x, y)-coordinates
	coords = np.zeros((68, 2), dtype=dtype)
	# loop over the 68 facial landmarks and convert them
	# to a 2-tuple of (x, y)-coordinates
	for i in range(0, 68):
		coords[i] = (shape.part(i).x, shape.part(i).y)
	# return the list of (x, y)-coordinates
	return coords

from collections import OrderedDict

# define a dictionary that maps the indexes of the facial
# landmarks to specific face regions

#For dlib’s 68-point facial landmark detector:
FACIAL_LANDMARKS_68_IDXS = OrderedDict([
	("mouth", (48, 68)),
	("inner_mouth", (60, 68)),
	("right_eyebrow", (17, 22)),
	("left_eyebrow", (22, 27)),
	("right_eye", (36, 42)),
	("left_eye", (42, 48)),
	("nose", (27, 36)),
	("jaw", (0, 17))
])

#For dlib’s 5-point facial landmark detector:
FACIAL_LANDMARKS_5_IDXS = OrderedDict([
	("right_eye", (2, 3)),
	("left_eye", (0, 1)),
	("nose", (4))
])

# in order to support legacy code, we'll default the indexes to the
# 68-point model
FACIAL_LANDMARKS_IDXS = FACIAL_LANDMARKS_68_IDXS

# %%
class FaceAligner:
    def __init__(self, predictor, desiredLeftEye=(0.35, 0.35),
        desiredFaceWidth=256, desiredFaceHeight=None):
        # store the facial landmark predictor, desired output left
        # eye position, and desired output face width + height
        self.predictor = predictor # 얼굴 랜드마크 예측 모델
        self.desiredLeftEye = desiredLeftEye # 원하는 출력 왼쪽 눈 위치를 지정
        self.desiredFaceWidth = desiredFaceWidth # 원하는 얼굴을 픽셀 단위로 정의, 기본값 256픽셀
        self.desiredFaceHeight = desiredFaceHeight #  원하는 얼굴 높이 값을 픽셀 단위로 지정
        # if the desired face height is None, set it to be the
        # desired face width (normal behavior)
        if self.desiredFaceHeight is None:
            self.desiredFaceHeight = self.desiredFaceWidth # 정사각형 이미지로 출력


    def align(self, image, gray, rect):
        # image: The RGB input image/ gray: The grayscale input image/ rect: The bounding box rectangle produced by dlib’s HOG face detector
        # convert the landmark (x, y)-coordinates to a NumPy array
        shape = self.predictor(gray, rect)
        shape = shape_to_np(shape)
        # extract the left and right eye (x, y)-coordinates
        if (len(shape)==68):
          (lStart, lEnd) = FACIAL_LANDMARKS_68_IDXS["left_eye"]
          (rStart, rEnd) = FACIAL_LANDMARKS_68_IDXS["right_eye"]
        else:
          (lStart, lEnd) = FACIAL_LANDMARKS_5_IDXS["left_eye"]
          (rStart, rEnd) = FACIAL_LANDMARKS_5_IDXS["right_eye"]

        leftEyePts = shape[lStart:lEnd]
        rightEyePts = shape[rStart:rEnd]

        # 각 눈의 질량 중심을 계산: 각 눈의 모든 (x, y) 점을 평균하여 각 눈의 중심, 즉 질량 중심을 계산
        leftEyeCenter = leftEyePts.mean(axis=0).astype("int")
        rightEyeCenter = rightEyePts.mean(axis=0).astype("int")

        # 눈 중심 사이의 각도를 계산
        dY = rightEyeCenter[1] - leftEyeCenter[1]
        dX = rightEyeCenter[0] - leftEyeCenter[0]
        angle = np.degrees(np.arctan2(dY, dX)) - 180 # 얼굴 회전의 각도를 계산

        # compute the desired right eye x-coordinate based on the desired x-coordinate of the left eye
        # 왼쪽 눈의 원하는 x좌표를 기반으로 원하는 오른쪽 눈 x 좌표를 계산
        desiredRightEyeX = 1.0 - self.desiredLeftEye[0]
        # determine the scale of the new resulting image by taking
        # the ratio of the distance between eyes in the *current*
        # image to the ratio of distance between eyes in the
        # *desired* image
        dist = np.sqrt((dX ** 2) + (dY ** 2))
        desiredDist = (desiredRightEyeX - self.desiredLeftEye[0])
        desiredDist *= self.desiredFaceWidth
        scale = desiredDist / dist


        # compute center (x, y)-coordinates (i.e., the median point)
        # between the two eyes in the input image
        eyesCenter = (int((leftEyeCenter[0] + rightEyeCenter[0]) // 2),
              int((leftEyeCenter[1] + rightEyeCenter[1]) // 2))
        # grab the rotation matrix for rotating and scaling the face
        M = cv2.getRotationMatrix2D(eyesCenter, angle, scale)
        # update the translation component of the matrix
        tX = self.desiredFaceWidth * 0.5
        tY = self.desiredFaceHeight * self.desiredLeftEye[1]
        M[0, 2] += (tX - eyesCenter[0])
        M[1, 2] += (tY - eyesCenter[1])

        # apply the affine transformation
        (w, h) = (self.desiredFaceWidth, self.desiredFaceHeight)
        output = cv2.warpAffine(image, M, (w, h),
            flags=cv2.INTER_CUBIC)
        # return the aligned face
        return output

# %%
import dlib
import imutils
from google.colab.patches import cv2_imshow
from collections import OrderedDict
import matplotlib.pyplot as plt

# %%
shape_predictor_path = "/content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/shape_predictor_68_face_landmarks.dat"

# %%
import os
from imutils import paths

# Set the directory containing the images and the output directory
input_dir = '/content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data'  # 입력 이미지 폴더 경로
output_dir = '/content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces'  # 출력 폴더 경로
os.makedirs(output_dir, exist_ok=True)  # 출력 폴더가 없으면 생성

# Initialize dlib's face detector and facial landmark predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor(shape_predictor_path)
fa = FaceAligner(predictor, desiredFaceWidth=256)

# Loop over the input images
imagePaths = list(paths.list_images(input_dir))  # 폴더 내 이미지 경로 가져오기
for (i, imagePath) in enumerate(imagePaths):
    print(f"[INFO] Processing image {i + 1}/{len(imagePaths)}: {imagePath}")

    # Load the image, resize it, and convert it to grayscale
    image = cv2.imread(imagePath)
    image = imutils.resize(image, width=800)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Detect faces in the grayscale image
    rects = detector(gray, 2)

    for rect in rects:
        # Align the face using facial landmarks
        faceAligned = fa.align(image, gray, rect)

        # Construct the new file name
        output_filename = f"aligned_{i + 1:03d}.jpg"  # 'aligned_001.jpg', 'aligned_002.jpg', ...
        output_path = os.path.join(output_dir, output_filename)

        # Save the aligned face
        cv2.imwrite(output_path, faceAligned)

print("[INFO] Face alignment complete.")
# Out:
# [INFO] Processing image 1/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3516.JPG
# [INFO] Processing image 2/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_2812.JPG
# [INFO] Processing image 3/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_4132.JPG
# [INFO] Processing image 4/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_2661.JPG
# [INFO] Processing image 5/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3438.JPG
# [INFO] Processing image 6/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/F00EE39E-E194-4AB1-B5DC-C8E6EEE632EF.jpg
# [INFO] Processing image 7/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/EB8AF79A-3EAC-4FBC-9F56-6738785888B4.jpg
# [INFO] Processing image 8/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/5F423B94-5EEC-4EC5-A992-DB095AAD1165.jpg
# [INFO] Processing image 9/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3018.jpg
# [INFO] Processing image 10/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3156.jpg
# [INFO] Processing image 11/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3155.jpg
# [INFO] Processing image 12/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3154.jpg
# [INFO] Processing image 13/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3148.jpg
# [INFO] Processing image 14/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3039.jpg
# [INFO] Processing image 15/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3038.jpg
# [INFO] Processing image 16/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_0200.jpg
# [INFO] Processing image 17/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_0037.jpg
# [INFO] Processing image 18/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3157.jpg
# [INFO] Processing image 19/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3158.jpg
# [INFO] Processing image 20/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3373.jpg
# [INFO] Processing image 21/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3577.jpg
# [INFO] Processing image 22/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_1947.jpg
# [INFO] Processing image 23/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_1497.jpg
# [INFO] Processing image 24/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_1531.jpg
# [INFO] Processing image 25/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_1945.jpg
# [INFO] Processing image 26/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_1498.jpg
# [INFO] Processing image 27/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_1528.jpg
# [INFO] Processing image 28/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_1494.jpg
# [INFO] Processing image 29/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_1929.jpg
# [INFO] Processing image 30/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_0682.jpg
# [INFO] Processing image 31/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_0201.jpg
# [INFO] Processing image 32/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_0661.jpg
# [INFO] Processing image 33/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_0204.jpg
# [INFO] Processing image 34/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_2643.jpg
# [INFO] Processing image 35/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_2642.jpg
# [INFO] Processing image 36/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_2510.jpg
# [INFO] Processing image 37/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_2545.jpg
# [INFO] Processing image 38/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_2544.jpg
# [INFO] Processing image 39/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_1949.jpg
# [INFO] Processing image 40/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_2508.jpg
# [INFO] Processing image 41/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_2546.jpg
# [INFO] Processing image 42/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_2596.jpg
# [INFO] Processing image 43/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_1948.jpg
# [INFO] Processing image 44/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3017.jpg
# [INFO] Processing image 45/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_2831.jpg
# [INFO] Processing image 46/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3016.jpg
# [INFO] Processing image 47/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_2848.jpg
# [INFO] Processing image 48/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_2845.jpg
# [INFO] Processing image 49/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_2847.jpg
# [INFO] Processing image 50/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_2846.jpg
# [INFO] Processing image 51/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_7745.jpg
# [INFO] Processing image 52/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3832.jpg
# [INFO] Processing image 53/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3676.jpg
# [INFO] Processing image 54/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_9659.jpg
# [INFO] Processing image 55/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3587.jpg
# [INFO] Processing image 56/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3594.jpg
# [INFO] Processing image 57/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_9657.jpg
# [INFO] Processing image 58/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3589.jpg
# [INFO] Processing image 59/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_9658.jpg
# [INFO] Processing image 60/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_9272.jpg
# [INFO] Processing image 61/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_9269.jpg
# [INFO] Processing image 62/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_7746.jpg
# [INFO] Processing image 63/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3879.jpg
# [INFO] Processing image 64/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3834.jpg
# [INFO] Processing image 65/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3878.jpg
# [INFO] Processing image 66/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3835.jpg
# [INFO] Processing image 67/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3833.jpg
# [INFO] Processing image 68/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3872.jpg
# [INFO] Processing image 69/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_4088.jpg
# [INFO] Processing image 70/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_4087.jpg
# [INFO] Processing image 71/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_3918.jpg
# [INFO] Processing image 72/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_4067.jpg
# [INFO] Processing image 73/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_4069.jpg
# [INFO] Processing image 74/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_4085.jpg
# [INFO] Processing image 75/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_4436.jpg
# [INFO] Processing image 76/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_4435.jpg
# [INFO] Processing image 77/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_4090.jpg
# [INFO] Processing image 78/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_4425.jpg
# [INFO] Processing image 79/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_4433.jpg
# [INFO] Processing image 80/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_4421.jpg
# [INFO] Processing image 81/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_4089.jpg
# [INFO] Processing image 82/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_4094.jpg
# [INFO] Processing image 83/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_5467.jpg
# [INFO] Processing image 84/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_5450.jpg
# [INFO] Processing image 85/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_4722.jpg
# [INFO] Processing image 86/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_5260.jpg
# [INFO] Processing image 87/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_5261.jpg
# [INFO] Processing image 88/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_6004.jpg
# [INFO] Processing image 89/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_5846.jpg
# [INFO] Processing image 90/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_5781.jpg
# [INFO] Processing image 91/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_5600.jpg
# [INFO] Processing image 92/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_5472.jpg
# [INFO] Processing image 93/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_5599.jpg
# [INFO] Processing image 94/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_7743.jpg
# [INFO] Processing image 95/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_7664.jpg
# [INFO] Processing image 96/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_7590.jpg
# [INFO] Processing image 97/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_7296.jpg
# [INFO] Processing image 98/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_7361.jpg
# [INFO] Processing image 99/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_7231.jpg
# [INFO] Processing image 100/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/IMG_7744.jpg
# [INFO] Face alignment complete.

# %% [markdown]
# ### 사진 하나가 잘 정렬이 안돼서 추가로 하나 더 넣음

# %%
# load the input image, resize it, and convert it to grayscale
input_image_path = '/content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data/증명사진.jpg'  # 처리할 단일 이미지 경로

# Load the input image, resize it, and convert it to grayscale
image = cv2.imread(input_image_path)  # 경로 변수 input_image_path 사용
if image is None:
    raise ValueError(f"[ERROR] Image not found at {input_image_path}")
image = imutils.resize(image, width=800)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Detect faces in the grayscale image
rects = detector(gray, 2)

# If faces are detected, align the first face
if len(rects) > 0:
    rect = rects[0]  # 첫 번째 얼굴만 처리
    faceAligned = fa.align(image, gray, rect)

    # Save the aligned face
    output_filename = "aligned_014.jpg"  # 출력 파일 이름
    output_path = os.path.join(output_dir, output_filename)
    cv2.imwrite(output_path, faceAligned)

    print(f"[INFO] Aligned face saved to {output_path}")
else:
    print("[INFO] No faces detected in the image.")
# Out:
# [INFO] Aligned face saved to /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_014.jpg

# %% [markdown]
# ## Bounding Box로 크롭하여 저장 (112*112 사이즈)

# %%
# Define paths
aligned_dir = '/content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces'  # 정렬된 얼굴이 저장된 폴더
cropped_dir = '/content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces'  # 크롭된 얼굴을 저장할 폴더
os.makedirs(cropped_dir, exist_ok=True)  # 출력 폴더 생성

# Desired output size
crop_size = 112

# Loop over the aligned images
aligned_image_paths = list(paths.list_images(aligned_dir))
for (i, aligned_image_path) in enumerate(aligned_image_paths):
    print(f"[INFO] Processing aligned image {i + 1}/{len(aligned_image_paths)}: {aligned_image_path}")

    # Load the aligned image
    image = cv2.imread(aligned_image_path)

    # Get the center of the image
    (h, w) = image.shape[:2]
    centerX, centerY = w // 2, h // 2

    # Compute the bounding box coordinates for the crop
    startX = max(0, centerX - crop_size // 2)
    startY = max(0, centerY - crop_size // 2)
    endX = min(w, centerX + crop_size // 2)
    endY = min(h, centerY + crop_size // 2)

    # Crop the image
    cropped_face = image[startY:endY, startX:endX]

    # Resize to 112x112 if not already the right size
    cropped_face = cv2.resize(cropped_face, (crop_size, crop_size), interpolation=cv2.INTER_AREA)

    # Save the cropped face
    cropped_filename = f"WSH{i + 1}.jpg"
    cropped_path = os.path.join(cropped_dir, cropped_filename)
    cv2.imwrite(cropped_path, cropped_face)

print("[INFO] Cropping and resizing complete.")
# Out:
# [INFO] Processing aligned image 1/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_001.jpg
# [INFO] Processing aligned image 2/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_002.jpg
# [INFO] Processing aligned image 3/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_003.jpg
# [INFO] Processing aligned image 4/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_004.jpg
# [INFO] Processing aligned image 5/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_005.jpg
# [INFO] Processing aligned image 6/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_009.jpg
# [INFO] Processing aligned image 7/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_010.jpg
# [INFO] Processing aligned image 8/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_011.jpg
# [INFO] Processing aligned image 9/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_012.jpg
# [INFO] Processing aligned image 10/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_013.jpg
# [INFO] Processing aligned image 11/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_015.jpg
# [INFO] Processing aligned image 12/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_016.jpg
# [INFO] Processing aligned image 13/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_017.jpg
# [INFO] Processing aligned image 14/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_018.jpg
# [INFO] Processing aligned image 15/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_019.jpg
# [INFO] Processing aligned image 16/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_020.jpg
# [INFO] Processing aligned image 17/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_021.jpg
# [INFO] Processing aligned image 18/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_022.jpg
# [INFO] Processing aligned image 19/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_024.jpg
# [INFO] Processing aligned image 20/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_025.jpg
# [INFO] Processing aligned image 21/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_026.jpg
# [INFO] Processing aligned image 22/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_027.jpg
# [INFO] Processing aligned image 23/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_030.jpg
# [INFO] Processing aligned image 24/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_031.jpg
# [INFO] Processing aligned image 25/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_033.jpg
# [INFO] Processing aligned image 26/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_034.jpg
# [INFO] Processing aligned image 27/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_035.jpg
# [INFO] Processing aligned image 28/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_037.jpg
# [INFO] Processing aligned image 29/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_038.jpg
# [INFO] Processing aligned image 30/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_039.jpg
# [INFO] Processing aligned image 31/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_040.jpg
# [INFO] Processing aligned image 32/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_041.jpg
# [INFO] Processing aligned image 33/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_042.jpg
# [INFO] Processing aligned image 34/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_043.jpg
# [INFO] Processing aligned image 35/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_044.jpg
# [INFO] Processing aligned image 36/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_045.jpg
# [INFO] Processing aligned image 37/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_046.jpg
# [INFO] Processing aligned image 38/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_047.jpg
# [INFO] Processing aligned image 39/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_048.jpg
# [INFO] Processing aligned image 40/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_049.jpg
# [INFO] Processing aligned image 41/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_050.jpg
# [INFO] Processing aligned image 42/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_051.jpg
# [INFO] Processing aligned image 43/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_052.jpg
# [INFO] Processing aligned image 44/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_053.jpg
# [INFO] Processing aligned image 45/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_055.jpg
# [INFO] Processing aligned image 46/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_056.jpg
# [INFO] Processing aligned image 47/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_057.jpg
# [INFO] Processing aligned image 48/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_059.jpg
# [INFO] Processing aligned image 49/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_060.jpg
# [INFO] Processing aligned image 50/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_061.jpg
# [INFO] Processing aligned image 51/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_062.jpg
# [INFO] Processing aligned image 52/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_063.jpg
# [INFO] Processing aligned image 53/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_064.jpg
# [INFO] Processing aligned image 54/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_065.jpg
# [INFO] Processing aligned image 55/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_066.jpg
# [INFO] Processing aligned image 56/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_067.jpg
# [INFO] Processing aligned image 57/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_068.jpg
# [INFO] Processing aligned image 58/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_069.jpg
# [INFO] Processing aligned image 59/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_070.jpg
# [INFO] Processing aligned image 60/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_071.jpg
# [INFO] Processing aligned image 61/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_072.jpg
# [INFO] Processing aligned image 62/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_073.jpg
# [INFO] Processing aligned image 63/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_074.jpg
# [INFO] Processing aligned image 64/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_075.jpg
# [INFO] Processing aligned image 65/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_076.jpg
# [INFO] Processing aligned image 66/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_077.jpg
# [INFO] Processing aligned image 67/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_078.jpg
# [INFO] Processing aligned image 68/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_079.jpg
# [INFO] Processing aligned image 69/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_080.jpg
# [INFO] Processing aligned image 70/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_081.jpg
# [INFO] Processing aligned image 71/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_082.jpg
# [INFO] Processing aligned image 72/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_083.jpg
# [INFO] Processing aligned image 73/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_084.jpg
# [INFO] Processing aligned image 74/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_085.jpg
# [INFO] Processing aligned image 75/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_086.jpg
# [INFO] Processing aligned image 76/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_087.jpg
# [INFO] Processing aligned image 77/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_088.jpg
# [INFO] Processing aligned image 78/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_090.jpg
# [INFO] Processing aligned image 79/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_091.jpg
# [INFO] Processing aligned image 80/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_092.jpg
# [INFO] Processing aligned image 81/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_093.jpg
# [INFO] Processing aligned image 82/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_094.jpg
# [INFO] Processing aligned image 83/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_095.jpg
# [INFO] Processing aligned image 84/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_096.jpg
# [INFO] Processing aligned image 85/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_097.jpg
# [INFO] Processing aligned image 86/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_098.jpg
# [INFO] Processing aligned image 87/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_099.jpg
# [INFO] Processing aligned image 88/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_100.jpg
# [INFO] Processing aligned image 89/89: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces/aligned_014.jpg
# [INFO] Cropping and resizing complete.

# %% [markdown]
# ### 89장밖에 안돼서 다시 추가로 정렬부터..

# %%
# Set the directory containing the images and the output directory
input_dir = '/content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1'  # 입력 이미지 폴더 경로
output_dir = '/content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1'  # 출력 폴더 경로
os.makedirs(output_dir, exist_ok=True)  # 출력 폴더가 없으면 생성

# Initialize dlib's face detector and facial landmark predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor(shape_predictor_path)
fa = FaceAligner(predictor, desiredFaceWidth=256)

# Loop over the input images
imagePaths = list(paths.list_images(input_dir))  # 폴더 내 이미지 경로 가져오기
for (i, imagePath) in enumerate(imagePaths):
    print(f"[INFO] Processing image {i + 1}/{len(imagePaths)}: {imagePath}")

    # Load the image, resize it, and convert it to grayscale
    image = cv2.imread(imagePath)
    image = imutils.resize(image, width=800)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Detect faces in the grayscale image
    rects = detector(gray, 2)

    for rect in rects:
        # Align the face using facial landmarks
        faceAligned = fa.align(image, gray, rect)

        # Construct the new file name
        output_filename = f"aligned_{i + 1:03d}.jpg"  # 'aligned_001.jpg', 'aligned_002.jpg', ...
        output_path = os.path.join(output_dir, output_filename)

        # Save the aligned face
        cv2.imwrite(output_path, faceAligned)

print("[INFO] Face alignment complete.")
# Out:
# [INFO] Processing image 1/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/beauty_1585711162357.jpeg
# [INFO] Processing image 2/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/beauty_1594099731114.jpeg
# [INFO] Processing image 3/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/beauty_1582711051674.jpeg
# [INFO] Processing image 4/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/beauty_1584092738902.jpeg
# [INFO] Processing image 5/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/beauty_1580955894583.jpeg
# [INFO] Processing image 6/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/beauty_1580955887600.jpeg
# [INFO] Processing image 7/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/beauty_1594099753978.jpeg
# [INFO] Processing image 8/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/beauty_1580955889229.jpeg
# [INFO] Processing image 9/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/beauty_1594099732358.jpeg
# [INFO] Processing image 10/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/IMG_2054.JPG
# [INFO] Processing image 11/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/IMG_7914.JPG
# [INFO] Processing image 12/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/IMG_7915.JPG
# [INFO] Processing image 13/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/IMG_1905.JPG
# [INFO] Processing image 14/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/IMG_1907.JPG
# [INFO] Processing image 15/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/IMG_1886.JPG
# [INFO] Processing image 16/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/IMG_6237.JPG
# [INFO] Processing image 17/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/DSCF0905.JPG
# [INFO] Processing image 18/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/IMG_6236.JPG
# [INFO] Processing image 19/19: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/Face_data1/IMG_7913.JPG
# [INFO] Face alignment complete.

# %%
# Define paths
aligned_dir = '/content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1'  # 정렬된 얼굴이 저장된 폴더
cropped_dir = '/content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces'  # 크롭된 얼굴을 저장할 폴더
os.makedirs(cropped_dir, exist_ok=True)  # 출력 폴더 생성

# Desired output size
crop_size = 112

# Loop over the aligned images
aligned_image_paths = list(paths.list_images(aligned_dir))
for (i, aligned_image_path) in enumerate(aligned_image_paths):
    print(f"[INFO] Processing aligned image {i + 1}/{len(aligned_image_paths)}: {aligned_image_path}")

    # Load the aligned image
    image = cv2.imread(aligned_image_path)

    # Get the center of the image
    (h, w) = image.shape[:2]
    centerX, centerY = w // 2, h // 2

    # Compute the bounding box coordinates for the crop
    startX = max(0, centerX - crop_size // 2)
    startY = max(0, centerY - crop_size // 2)
    endX = min(w, centerX + crop_size // 2)
    endY = min(h, centerY + crop_size // 2)

    # Crop the image
    cropped_face = image[startY:endY, startX:endX]

    # Resize to 112x112 if not already the right size
    cropped_face = cv2.resize(cropped_face, (crop_size, crop_size), interpolation=cv2.INTER_AREA)

    # Save the cropped face
    cropped_filename = f"WSH{i + 90}.jpg"
    cropped_path = os.path.join(cropped_dir, cropped_filename)
    cv2.imwrite(cropped_path, cropped_face)

print("[INFO] Cropping and resizing complete.")
# Out:
# [INFO] Processing aligned image 1/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_014.jpg
# [INFO] Processing aligned image 2/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_001.jpg
# [INFO] Processing aligned image 3/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_002.jpg
# [INFO] Processing aligned image 4/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_003.jpg
# [INFO] Processing aligned image 5/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_004.jpg
# [INFO] Processing aligned image 6/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_005.jpg
# [INFO] Processing aligned image 7/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_006.jpg
# [INFO] Processing aligned image 8/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_007.jpg
# [INFO] Processing aligned image 9/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_008.jpg
# [INFO] Processing aligned image 10/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_009.jpg
# [INFO] Processing aligned image 11/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_010.jpg
# [INFO] Processing aligned image 12/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_011.jpg
# [INFO] Processing aligned image 13/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_012.jpg
# [INFO] Processing aligned image 14/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_013.jpg
# [INFO] Processing aligned image 15/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_016.jpg
# [INFO] Processing aligned image 16/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_017.jpg
# [INFO] Processing aligned image 17/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_018.jpg
# [INFO] Processing aligned image 18/18: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/aligned_faces1/aligned_019.jpg
# [INFO] Cropping and resizing complete.

# %% [markdown]
# ### 몇개 골라내서 100장 사진 전처리 완!

# %% [markdown]
# ### 크롭된 사진 크기가 모두 112*112인지 확인

# %%
# Loop over the cropped images
cropped_image_paths = list(paths.list_images(cropped_dir))
for (i, cropped_image_path) in enumerate(cropped_image_paths):
    print(f"[INFO] Processing cropped image {i + 1}/{len(cropped_image_paths)}: {cropped_image_path}")

    # Load the cropped image
    image = cv2.imread(cropped_image_path)

    # Check if the image is loaded successfully
    if image is None:
        print(f"[ERROR] Failed to load image {cropped_image_path}")
        continue  # Skip to the next image if loading fails

    # Get the size of the image (height, width, channels)
    (h, w) = image.shape[:2]

    # Print the size of the image
    print(f"[INFO] Cropped image size: {w}x{h}")

print("[INFO] Cropped image size checking complete.")
# Out:
# [INFO] Processing cropped image 1/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH1.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 2/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH2.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 3/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH3.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 4/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH4.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 5/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH5.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 6/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH6.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 7/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH7.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 8/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH8.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 9/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH9.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 10/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH10.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 11/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH11.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 12/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH12.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 13/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH13.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 14/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH14.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 15/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH15.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 16/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH16.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 17/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH17.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 18/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH18.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 19/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH19.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 20/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH20.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 21/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH21.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 22/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH22.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 23/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH23.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 24/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH24.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 25/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH25.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 26/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH26.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 27/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH27.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 28/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH28.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 29/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH29.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 30/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH30.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 31/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH31.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 32/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH32.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 33/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH33.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 34/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH34.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 35/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH35.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 36/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH36.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 37/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH37.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 38/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH38.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 39/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH39.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 40/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH40.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 41/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH41.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 42/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH43.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 43/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH44.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 44/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH45.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 45/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH46.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 46/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH47.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 47/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH48.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 48/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH49.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 49/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH50.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 50/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH51.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 51/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH52.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 52/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH53.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 53/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH54.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 54/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH55.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 55/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH56.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 56/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH57.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 57/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH58.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 58/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH59.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 59/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH60.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 60/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH61.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 61/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH62.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 62/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH63.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 63/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH64.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 64/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH65.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 65/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH66.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 66/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH67.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 67/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH68.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 68/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH69.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 69/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH70.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 70/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH71.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 71/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH72.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 72/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH73.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 73/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH74.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 74/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH75.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 75/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH76.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 76/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH77.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 77/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH78.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 78/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH79.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 79/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH80.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 80/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH81.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 81/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH82.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 82/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH83.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 83/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH84.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 84/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH85.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 85/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH86.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 86/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH87.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 87/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH88.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 88/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH89.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 89/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH90.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 90/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH91.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 91/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH92.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 92/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH93.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 93/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH94.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 94/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH95.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 95/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH96.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 96/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH97.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 97/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH100.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 98/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH99.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 99/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH42.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Processing cropped image 100/100: /content/drive/MyDrive/Colab Notebooks/DAT 4th/팀프로젝트/cropped_faces/WSH98.jpg
# [INFO] Cropped image size: 112x112
# [INFO] Cropped image size checking complete.
